# %% [markdown]
# <a href="https://colab.research.google.com/github/NikTamu3/myproject/blob/main/MNIST2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,Conv2D,MaxPooling2D,Flatten,Dense,Dropout

# %%
(X_train,Y_train),(X_test,Y_test)=mnist.load_data()
X_train=X_train/255.0
X_test=X_test/255.0

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
fig,ax=plt.subplots(ncols=4,figsize=(20,20))
for i in range(4):
  ax[i].imshow(X_train[i],cmap='gray')
plt.show()

# %%
from tensorflow.keras import optimizers,layers

# %%
input=Input((28,28,1))
c1=Conv2D(32,(3,3),activation='relu')(input)
c1=MaxPooling2D((2,2))(c1)

c2=Conv2D(64,(3,3),activation='relu')(c1)
c2=MaxPooling2D((2,2))(c2)

c3=Conv2D(128,(3,3),activation='relu')(c2)
c3=MaxPooling2D((2,2))(c3)

flatten=Flatten()(c3)
x=Dense(512,activation='relu')(flatten)
outputs=Dense(1,activation='sigmoid')(x)

model=tf.keras.Model(inputs=[input],outputs=[outputs])

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=0.001),loss=tf.losses.SparseCategoricalCrossentropy(),metrics=['accuracy'])

# %%
histroy=model.fit(X_train,Y_train,validation_split=0.2,epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.1002 - loss: nan - val_accuracy: 0.0995 - val_loss: nan
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0986 - loss: nan - val_accuracy: 0.0995 - val_loss: nan
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.0975 - loss: nan - val_accuracy: 0.0995 - val_loss: nan
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0970 - loss: nan - val_accuracy: 0.0995 - val_loss: nan
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0971 - loss: nan - val_accuracy: 0.0995 - val_loss: nan
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0979 - loss: nan - val_accuracy: 0.0995 - val_loss: nan
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0986 - loss: nan - val_accuracy: 0.0995 - val_loss: nan
# Epoch 8/10
# ...

# %%
plt.plot(histroy.history['accuracy'],label='train_acc')
plt.plot(histroy.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %%
test_loss,test_accuracy=model.evaluate(X_test,Y_test)
print("Test Loss:",test_loss)
print("Test Accuracy:",test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0924 - loss: nan
# Test Loss: nan
# Test Accuracy: 0.09799999743700027

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input,Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras import optimizers

# %%
from tensorflow.keras.datasets import mnist

# %%
(X_train,Y_train),(X_test,Y_test)=mnist.load_data()

# %%
(X_train,Y_train),(X_test,Y_test)=mnist.load_data()
X_train=X_train/255.0
X_test=X_test/255.0

# %%
print(X_train.shape)
# Out:
# (60000, 28, 28)

# %%
import numpy as np
uni=np.unique(X_train[0])
print(uni)
# Out:
# [0.         0.00392157 0.00784314 0.01176471 0.03529412 0.04313725
#  0.05490196 0.0627451  0.07058824 0.09019608 0.09411765 0.09803922
#  0.10196078 0.10588235 0.11764706 0.1372549  0.14117647 0.15294118
#  0.16862745 0.17647059 0.18039216 0.19215686 0.21568627 0.21960784
#  0.25098039 0.25882353 0.2745098  0.30588235 0.31372549 0.31764706
#  0.32156863 0.35294118 0.36470588 0.36862745 0.41960784 0.42352941
#  0.44705882 0.46666667 0.49411765 0.49803922 0.50980392 0.51764706
#  0.52156863 0.52941176 0.53333333 0.54509804 0.58039216 0.58823529
#  0.60392157 0.61176471 0.62745098 0.65098039 0.66666667 0.67058824
#  0.6745098  0.68627451 0.71372549 0.71764706 0.72941176 0.73333333
#  0.74509804 0.76470588 0.77647059 0.78823529 0.80392157 0.81176471
#  0.83137255 0.83529412 0.85882353 0.86666667 0.88235294 0.88627451
#  0.89803922 0.93333333 0.94117647 0.94509804 0.94901961 0.95686275
#  0.96862745 0.97647059 0.98039216 0.98431373 0.98823529 0.99215686
#  1.        ]

# %%
print(Y_train[:10])
# Out:
# [5 0 4 1 9 2 1 3 1 4]

# %%
import matplotlib.pyplot as plt
for i in range(5):
  plt.imshow(X_train[i],cmap='gray')
  plt.axis("off")
  plt.show()

# %%
inputs=Input((28,28,1))
c1=Conv2D(32,(3,3),activation='relu')(inputs)
c1=MaxPooling2D((2,2))(c1)

c2=Conv2D(32,(3,3),activation='relu')(c1)
c2=MaxPooling2D((2,2))(c2)

c3=Conv2D(32,(3,3),activation='relu')(c2)
c3=MaxPooling2D((2,2))(c3)

x=Dropout(0.2)(c3)
flatten=Flatten()(x)

y=Dense(256,activation='relu')(flatten)
y=Dense(10,activation='softmax')(y)

model=Model(inputs,y)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_10 (InputLayer)          │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 11, 11, 32)          │           9,248 │
# ...

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=0.001),loss=tf.losses.SparseCategoricalCrossentropy(),metrics=['accuracy'])

# %%
hist=model.fit(X_train,Y_train,validation_split=0.2,epochs=30)
# Out:
# Epoch 1/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9956 - loss: 0.0141 - val_accuracy: 0.9847 - val_loss: 0.0716
# Epoch 2/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9944 - loss: 0.0179 - val_accuracy: 0.9868 - val_loss: 0.0588
# Epoch 3/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9949 - loss: 0.0175 - val_accuracy: 0.9851 - val_loss: 0.0628
# Epoch 4/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9944 - loss: 0.0174 - val_accuracy: 0.9852 - val_loss: 0.0634
# Epoch 5/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9945 - loss: 0.0167 - val_accuracy: 0.9838 - val_loss: 0.0713
# Epoch 6/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9946 - loss: 0.0166 - val_accuracy: 0.9868 - val_loss: 0.0628
# Epoch 7/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9946 - loss: 0.0157 - val_accuracy: 0.9864 - val_loss: 0.0562
# Epoch 8/30
# ...

# %%
plt.plot(histroy.history['accuracy'],label='train_acc')
plt.plot(histroy.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %%
test_acc,test_loss=model.evaluate(X_test,Y_test)
print(f"test_accuracy:{test_acc},test_loss:{test_loss}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9842 - loss: 0.0763
# test_accuracy:0.06642856448888779,test_loss:0.986299991607666

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import cv2 as cv

# %%
img_path="/content/no3.jpg"

# %%
plt.imshow(img,cmap='gray')
plt.show()

# %%
img=cv.imread(img_path)
img=cv.cvtColor(img,cv.COLOR_BGR2RGB)
img=cv.cvtColor(img,cv.COLOR_RGB2GRAY)

# %%
import os
path=os.path.join("/content/sample_data/image",'grayscale.jpg')
cv.imwrite(path,img)
# Out:
# True

# %%
im_path="/content/sample_data/image/grayscale.jpg"
img=image.load_img(im_path,target_size=(28,28,1))

# %%
img_array=image.img_to_array(img)/255.0

# %%
plt.imshow(img_array,cmap='gray')
plt.show()

# %%
predict=model.predict(img_array)
if predict>=0.5:
  print("The number is 1")
else:
  print("The number is 0")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-d8e12081c242> in <cell line: 1>()
# ----> 1 predict=model.predict(img_array)
#       2 if predict>=0.5:
#       3   print("The number is 1")
#       4 else:
#       5   print("The number is 0")
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     243                 if spec_dim is not None and dim is not None:
# ...
